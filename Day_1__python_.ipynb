# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
2*10
# Out:
# 20

# %%
3+4
# Out:
# 7

# %%
type(10)
# Out:
# int

# %%
type(10.0)
# Out:
# float

# %%
type("abc")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(True or False)
# Out:
# bool

# %%
eno=10
ename="abc"
esal=260000
print("the given eno is",eno)
print("the given ename is",ename)
print("the given esal is ",esal)
# Out:
# the given eno is 10
# the given ename is abc
# the given esal is  260000

# %%
# Out:
# enter a value100
# enter b value200
# 100200

# %%
eno=10
Ename="Pc"
esal=345.45
print("The give eno is",eno)
print("the give Ename is",Ename)
print("the given esal is",esal)
# Out:
# The give eno is 10
# the give Ename is Pc
# the given esal is 345.45

# %%
a=int(input("enter a value:"))
b=int(input("enter b value:"))
print(type(a))
print(type(b))
print(a+b)
# Out:
# enter a value:100
# enter b value:200
# <class 'int'>
# <class 'int'>
# 300

# %%
eno=int(input("enter emplyee number:"))
Ename=(input("enter employee name:"))
esal=float(input("enter employee salary"))
print("The give eno is",eno)
print("the give Ename is",Ename)
print("the given esal is",esal)
# Out:
# enter emplyee number:100
# enter employee name:pranuthi
# enter employee salary2700000
# The give eno is 100
# the give Ename is pranuthi
# the given esal is 2700000.0

# %%
#Write a python program to enter radius of circle and find the area?
radius=int(input("Enter radius the radius of cricle :"))
pi=3.14
area=pi*radius*radius
print("The area of cricle is ",area)
# Out:
# Enter radius the radius of cricle :77
# The area of cricle is  18617.06

# %%
#write a python program to enter radius of circumference of rectangle?
l=int(input("enter lenght of rectangle:"))
b=int(input("enter breath of rectangle:"))
area=l*b
circumference=2*(l+b)
print("the area of rectangle",area)
print("the circumference of rectangle",circumference)
# Out:
# enter lenght of rectangle:20
# enter breath of rectangle:10
# the area of rectangle 200
# the circumference of rectangle 60

# %%
a=10
b=2
if a>b :
  print("a is big")
else:
  print("b is big")
# Out:
# a is big

# %%
#Write a python to check the person wheather eligible for voting or not
age=int(input("enter age of person:"))

if age>=18:

    print("eligible for voting")
else:

    print("not eligible for voting")
# Out:
# enter age of person:21
# eligible for voting

# %%
from ast import Num
# Write a python program to check the given number is positive or negative or Zero

num=int(input("enter number:"))
if num>0:
   print("positive")
elif num<0:
   print("negitive")
else:
   print("Zero")
# Out:
# enter number:12
# positive
